# %% [markdown]
# ### purpose
#
# just a place to kick off the rest of the climate outlier scenario runs, I did most manually via command line, but wanted to document some examples

# %%
from os import path as op
import os

minseed = 1575
maxseed = minseed + 225

outerdir = f'/home/b.lind/offsets/run_20220919_{minseed}-{maxseed}'
outlier_outerdir = f'/home/b.lind/offsets/climate_outlier_runs/run_20220919_{minseed}-{maxseed}'

assert op.exists(outlier_outerdir) is False

# %%
os.chdir('/home/b.lind/code/MVP-offsets/01_src')

# %%
# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# Environment info :
# #########################################################
# Today:	June 02, 2023 - 10:39:46
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit c721bd0d89c1e150e17a4e0739c26e4296405233
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Wed May 10 15:13:03 2023 -0400
#
# Current commit of MVP_offsets:
# commit 060db40dff8355d2087deab28bd695fcccee8f49
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Thu May 18 12:50:56 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# myslurm                     NA
# numpy                       1.22.1
# pandas                      1.3.5
# ...

# %% [markdown]
# # kick off 1-trait jobs

# %%
from pythonimports import *

import MVP_summary_functions as mvp

os.chdir('/home/b.lind/code/MVP-offsets/01_src')

mvp.latest_commit()
session_info.show()
# Out:
# #########################################################
# Today:	September 26, 2023 - 09:36:16 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# myslurm                     NA
# numpy                       1.22.1
# ...

# %%
def get_dirs(minseed):
    assert minseed % 225 == 0
    
    maxseed = minseed + 225

    outerdir = f'/home/b.lind/offsets/1-trait_run_20220919_{minseed}-{maxseed}'
    outlier_outerdir = f'/home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_{minseed}-{maxseed}'
    
    print(outlier_outerdir)

    assert op.exists(outlier_outerdir) is False, outlier_outerdir
    
    return outerdir, outlier_outerdir

# %%
outerdir, outlier_outerdir = get_dirs(0)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:36:20 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# myslurm                     NA
# numpy                       1.22.1
# ...

# %%
Squeue(p='short', states='PD').update(to_partition='long', num_jobs=0.5)
# Out:
# update: 100%|███████████████| 4/4 [00:00<00:00, 14.93it/s]

# %%
outerdir, outlier_outerdir = get_dirs(225)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_225-450
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:38:24 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(450)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_450-675
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:38:40 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(675)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_675-900
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:38:54 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(900)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_900-1125
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:39:09 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(1125)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_1125-1350
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:39:19 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(1350)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_1350-1575
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:39:31 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(1575)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_1575-1800
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:39:48 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(1800)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_1800-2025
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:39:57 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
outerdir, outlier_outerdir = get_dirs(2025)

# !python MVP_14_climate_outlier_fit_GF.py $outerdir $outlier_outerdir
# Out:
# /home/b.lind/offsets/climate_outlier_runs/1-trait_run_20220919_2025-2250
#
# Environment info :
# #########################################################
# Today:	September 26, 2023 - 09:40:11 EDT
# python version: 3.8.5
# conda env: mvp_env
#
# Current commit of pythonimports:
# commit 9493334506a1f2926fba0734fa74ba2f87194611
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Fri Jun 30 09:41:00 2023 -0400
#
# Current commit of MVP_offsets:
# commit 4df974c6efa2868236cc272fcc84eb1059ca8aef
# Author: Brandon Lind <lind.brandon.m@gmail.com>
# Date:   Tue Sep 26 09:31:50 2023 -0400
# #########################################################
#
# -----
# MVP_02_fit_gradient_forests NA
# MVP_summary_functions       NA
# balance_queue               NA
# cartopy                     0.20.2
# ipyparallel                 7.1.0
# matplotlib                  3.5.2
# myclasses                   NA
# myfigs                      NA
# mymaps                      NA
# ...

# %%
Squeue(p='short', states='PD').update(to_partition='long', num_jobs=0.5)
# Out:
# update: 100%|███████████████| 27/27 [00:01<00:00, 15.89it/s]

# %%
Squeue()
# Out:
# 🗒️  Queue Summary:
#
# {'long': {'PD': 19, 'R': 9},
#  'lotterhos': {'R': 1},
#  'short': {'PD': 27, 'R': 11}}

# %%
Squeue(exclude='watcher')
# Out:
# 🗒️  Queue Summary:
#
# {'long': {'PD': 19, 'R': 9},
#  'lotterhos': {'R': 1},
#  'short': {'PD': 17, 'R': 11}}
